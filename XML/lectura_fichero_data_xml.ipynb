# %%
#VAMOS A ABRIR EL ARCHIVO XML PARA LEERLO.

import xml.etree.ElementTree as ET
from os import getcwd, listdir


import re


tree = ET.parse('data_xml.xml')
root = tree.getroot()

print(root)
for row in root:
    print(row.tag)
    for child in row:
        print('  ',child.tag, child.text)
# Out:
# <Element 'data' at 0x7efd0809d810>
# row
#    level_0 0
#    index 0
#    time 910
#    age 50-54
#    gender 0
# row
#    level_0 1
#    index 1
#    time 784
#    age 50-54
#    gender 0
# row
#    level_0 2
#    index 2
#    time 924
#    age 22-24
#    gender 0
# row
#    level_0 3
#    index 3
#    time 575
#    age 45-49
#    gender 0
# row
#    level_0 4
#    index 4
#    time 781
#    age 45-49
#    gender 0
# row
#    level_0 5
#    index 5
#    time 1020
#    age 25-29
#    gender 1
# row
#    level_0 6
#    index 6
#    time 141
#    age 18-21
#    gender 1
# row
#    level_0 7
#    index 7
#    time 484
#    age 30-34
#    gender 0
# row
#    level_0 8
#    index 8
#    time 1744
#    age 22-24
#    gender 0
# row
#    level_0 9
#    index 9
#    time 655
#    age 30-34
#    gender 0
# row
#    level_0 10
#    index 10
#    time 1777
#    age 40-44
#    gender 0
# row
#    level_0 11
#    index 11
#    time 3081
#    age 18-21
#    gender 1
# row
#    level_0 12
# ...
